# %% [markdown]
# *installing yfinance library*

# %%
# !pip install yfinance==0.2.4

# %% [markdown]
# # Getting Data from JSON file

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/amd.json
# Out:
# --2023-07-18 12:38:50--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/amd.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5838 (5.7K) [application/json]
# Saving to: ‘amd.json’
#
# amd.json            100%[===================>]   5.70K  --.-KB/s    in 0s
#
# 2023-07-18 12:38:51 (754 MB/s) - ‘amd.json’ saved [5838/5838]

# %%
import json
with open('amd.json') as json_file:
    amd_info = json.load(json_file)

amd_info_list = []
for key, value in amd_info.items():
    amd_info_list.append([key, value])

df = pd.DataFrame(amd_info_list)
df
# Out:
#                        0                                                  1
# 0                    zip                                              95054
# 1                 sector                                         Technology
# 2      fullTimeEmployees                                              15500
# 3    longBusinessSummary  Advanced Micro Devices, Inc. operates as a sem...
# 4                   city                                        Santa Clara
# ..                   ...                                                ...
# 147              bidSize                                                900
# 148              dayHigh                                             125.66
# 149   regularMarketPrice                                             119.22
# 150       preMarketPrice                                             116.98
# 151             logo_url                  https://logo.clearbit.com/amd.com
#
# [152 rows x 2 columns]

# %%
amd_info['country']
# Out:
# 'United States'

# %%
amd_info['sector']
# Out:
# 'Technology'

# %% [markdown]
# # extracting data using `Ticker` module

# %%
import yfinance as yf
import pandas as pd

# %%
amd = yf.Ticker("AMD")

amd_share_price_data = amd.history(period="max")
amd_share_price_data['Volume'][0]
# Out:
# 219600

# %%
amd = yf.Ticker("AMD")

amd_share_price_data = amd.history(period="1y")
amd_share_price_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-07-18 00:00:00-04:00   82.209999   84.470001   80.940002   81.430000
# 2022-07-19 00:00:00-04:00   82.760002   86.410004   82.190002   85.879997
# 2022-07-20 00:00:00-04:00   85.389999   89.919998   85.080002   89.430000
# 2022-07-21 00:00:00-04:00   89.599998   91.580002   88.220001   91.089996
# 2022-07-22 00:00:00-04:00   90.199997   90.690002   87.040001   88.099998
# ...                               ...         ...         ...         ...
# 2023-07-11 00:00:00-04:00  111.660004  113.269997  109.500000  111.320000
# 2023-07-12 00:00:00-04:00  112.889999  115.400002  112.309998  114.580002
# 2023-07-13 00:00:00-04:00  115.760002  116.160004  113.580002  115.919998
# 2023-07-14 00:00:00-04:00  116.169998  122.120003  115.250000  115.940002
# 2023-07-17 00:00:00-04:00  115.949997  118.839996  112.730003  118.320000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
amd_share_price_data.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---
#
#
#
# ---
